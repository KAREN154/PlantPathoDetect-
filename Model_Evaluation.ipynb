# %% [markdown]
# <a href="https://colab.research.google.com/github/KAREN154/PlantPathoDetect-/blob/main/Model_Evaluation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Model Evaluation

# %% [markdown]
# ### Tomato Model Evaluation

# %% [markdown]
# - This report provides a comparative analysis of different deep learning models used for tomato disease classification. The models evaluated include Augmented CNN, EfficientNetV2B0, ResNet50, MobileNet, and DenseNet. The key performance metrics considered are accuracy, precision, recall, and F1-score.
# ***
#
# **Model Performance Summary**
#
# 1. Augmented CNN Model
#
# - Test Loss: 0.64458
# - Test Accuracy: 73.93%
#
# - Best Class Performance: Healthy (Precision: 0.96, Recall: 0.98, F1-Score: 0.97)
#
# - Overall Accuracy: 91%
#
# - Weighted Avg F1-Score: 0.91
#
# 2. EfficientNetV2B0 Model
#
# - Overall Accuracy: 65%
# - Best Class Performance: Healthy (Precision: 0.94, Recall: 0.90, F1-Score: 0.92)
# - Lowest Performing Class: Early Blight (Precision: 0.51, Recall: 0.54, F1-Score: 0.53)
# - Weighted Avg F1-Score: 0.65
#
# 3. ResNet50 Model
#
# - Overall Accuracy: 89%
# - Weighted F1-Score: 0.89
# - Best Class Performance: Healthy (Precision: 0.98, Recall: 0.94, F1-Score: 0.96)
# - Lowest Performing Class: Early Blight (Precision: 0.77, Recall: 0.83, F1-Score: 0.80)
#
# 4. MobileNet Model
# - Overall Accuracy: 73%
# - Best Class Performance: Healthy (Precision: 0.83, Recall: 1.00, F1-Score: 0.91)
# - Lowest Performing Class: Early Blight (Precision: 0.66, Recall: 0.44, F1-Score: 0.53)
# - Weighted Avg F1-Score: 0.72
#
# 5. DenseNet Model
# - Overall Accuracy: Not explicitly provided, but results suggest it performs around 73%.
# - Best Class Performance: Yellow Leaf Curl Virus (Precision: 1.00, Recall: 0.92, F1-Score: 0.96)
#
# - Weighted Avg F1-Score: Not explicitly provided but estimated around 0.72.
#
# **Best Performing Model**
#
# - Based on the evaluation metrics, the Augmented CNN Model is the best-performing model with:
# - Highest Accuracy (91%)
# - Highest Weighted Average F1-Score (0.91)
# - Consistent Performance Across Classes
#
# **Conclusion**
# - Augmented CNN is the recommended model for tomato disease classification due to its superior accuracy and overall balanced performance.
#
# - ResNet50 is a strong alternative with an accuracy of 89% and a weighted F1-score of 0.89, making it a viable second choice.
#
# - EfficientNetV2B0 performed the worst, struggling with classifying Early Blight and Late Blight effectively.
#
# - MobileNet and DenseNet provided moderate results but were outperformed by Augmented CNN and ResNet50.

# %% [markdown]
# ### Potato Model Evaluation

# %% [markdown]
#  - The Potato Inception Model demonstrates strong performance in classifying Early Blight, Late Blight, and Healthy potato leaves. The evaluation results highlight its effectiveness, particularly in terms of precision, recall, and F1-score.
#
# **Performance Analysis**
# - The model achieved an accuracy of 94%, with a weighted F1-score of 0.94 across all classes.
# Early Blight had the lowest recall (0.96), while Late Blight had the lowest F1-score (0.91), indicating slight challenges in detecting some Late Blight cases.
# Improved Results:
#
# - After further optimization, the model improved significantly, reaching 98% accuracy and a weighted F1-score of 0.98.
# All three classes achieved consistently high precision and recall, demonstrating a well-balanced model with minimal misclassifications.
# Comparison with CNN Model on Augmented Data:
#
# - The CNN model tested on augmented data had a test accuracy of 73.93%, significantly lower than the Potato Inception Model.
#
# This suggests that the Potato Inception Model generalizes better and is more effective in real-world scenarios.
# Key Strengths:
# ✔️ High precision and recall across all categories, ensuring reliable classification.
# ✔️ Improved performance after further fine-tuning, reaching near-perfect scores.
# ✔️ Consistent and balanced predictions across all classes.
#
# Areas for Improvement:
# - The model initially struggled with detecting some Late Blight cases (F1-score of 0.91). Further refinement could enhance robustness.
# - Test accuracy for the CNN model on augmented data was relatively low (73.93%), suggesting augmentation strategies should be optimized.
#
# **Conclusion:**
#
# - The Potato Inception Model is highly effective for potato disease classification, achieving an impressive 98% accuracy in its final evaluation. It significantly outperforms the CNN model on augmented data, making it a reliable choice for real-world applications in early disease detection and agricultural monitoring. Future improvements can focus on refining the model’s performance on difficult cases and optimizing data augmentation techniques for further robustness.

# %% [markdown]
# ### Maize Model Evaluation

# %% [markdown]
# Model Evaluation for Maize Disease Classification
# This evaluation compares the performance of four deep learning models—Inception, DenseNet, EfficientNet, and ResNet—on a maize disease classification task with three classes: Cercospora Leaf Spot, Healthy, and Northern Leaf Blight. The models were evaluated using precision, recall, F1-score, and accuracy.
#
# 1. Model Performance Summary
#
# Model	Accuracy	Weighted F1 Score	Strengths	Weaknesses
# Inception	90%	0.89	High precision across all classes	Struggles with recall for Cercospora Leaf Spot (0.71)
# DenseNet	93%	0.93	Best overall performance, with Healthy class reaching 100% accuracy	Slight recall dip in Cercospora Leaf Spot (0.83)
# EfficientNet	93%	0.93	Balanced precision & recall across all classes	None (performs almost identically to DenseNet)
# ResNet	82%	0.81	Decent performance on Healthy class (0.94 recall)	Cercospora Leaf Spot recall is only 0.59, impacting overall accuracy
#
# 2. Best Performing Model
# DenseNet and EfficientNet performed the best, both achieving 93% accuracy and a weighted F1-score of 0.93.
# Between these two, EfficientNet had slightly better recall balance across all classes, making it the most reliable choice.
#
# 3. Model Strengths & Weaknesses
# Inception performed well overall but struggled with Cercospora Leaf Spot detection (low recall: 0.71).
# DenseNet and EfficientNet were the best models, maintaining a strong balance across all metrics.
# ResNet performed the worst, with only 82% accuracy, primarily due to poor recall in Cercospora Leaf Spot detection.
#
# 4. Recommendation
# If overall accuracy and balance are the priority, EfficientNet is the best model.
# If you want consistent high precision and recall, DenseNet is equally good.
# Avoid ResNet for this task due to poor performance
